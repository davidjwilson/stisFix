# %% [markdown]
# Fixing Boris's new E140M data. Check out a simple coadd, and stis blaze fix. If inadequate, try and make a new flat

# %%
#first get the python modules we need
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import os
import glob
from astropy.convolution import convolve, Box1DKernel
from astropy.table import Table
import astropy.units as u
from astropy.modeling import models, fitting

#matplotlib set up
# %matplotlib inline
from matplotlib import rcParams
rcParams["figure.figsize"] = (14, 5)
rcParams["font.size"] = 20
#rcParams['text.latex.unicode']=False
#rcParams["text.usetex"]=True

# %%
import stisblazefix

# %%
stisblazefix.__file__
# Out:
# '/home/david/anaconda3/envs/astroconda/lib/python3.7/site-packages/stisblazefix-1.2-py3.7.egg/stisblazefix/__init__.py'

# %%
x1ds = glob.glob('x1d_files/*x1d.fits')
x1ds
# Out:
# ['x1d_files/o4z101020_x1d.fits',
#  'x1d_files/o62w01030_x1d.fits',
#  'x1d_files/o4z102020_x1d.fits',
#  'x1d_files/odnu0k010_x1d.fits',
#  'x1d_files/ocvi42010_x1d.fits',
#  'x1d_files/o62w01020_x1d.fits',
#  'x1d_files/obovs1010_x1d.fits',
#  'x1d_files/o62w01010_x1d.fits',
#  'x1d_files/ocvi28010_x1d.fits',
#  'x1d_files/ocvi08010_x1d.fits']

# %%
for x in x1ds:
    data = fits.getdata(x, 1)
    for dt in data[::-1]:
        plt.plot(dt['WAVELENGTH'][(dt['WAVELENGTH'] >1160) & (dt['FLUX'] > 0)][10:-10], dt['FLUX'][(dt['WAVELENGTH'] >1160) & (dt['FLUX'] > 0)][10:-10])
    #plt.ylabel(b'Flux (erg/s/cm2/Angstrom)')
    #plt.xlim(1620, 1680)
    plt.show()

# %%
#stisblazefix.fluxfix(x1ds, 'basic_fix.pdf')

# %%
x1fs = glob.glob('x1d_files/*x1f.fits')

# %%
for x in x1fs:
    data = fits.getdata(x, 1)
    for dt in data[::-1]:
        plt.plot(dt['WAVELENGTH'][dt['WAVELENGTH'] >1160][10:-10], dt['FLUX'][dt['WAVELENGTH'] >1160][10:-10])
    #plt.ylabel(b'Flux (erg/s/cm2/Angstrom)')
    #plt.xlim(1620, 1680)
    plt.show()
